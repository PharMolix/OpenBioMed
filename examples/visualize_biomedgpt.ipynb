# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))
plt.rcParams.update({'font.size': 24})
x = np.arange(10)
y1 = np.array([24.3, 30.6, 35.5, 44, 44.7, 57.6, 48.2, 48.3, 50.5, 51.4])
y2 = np.array([5.2, 3.7, 21.9, 73.2, 63.9, 79.0, 73.4, 75.5, 69.5, 77.1])
y3 = np.array([27.1, 27.2, 34.4, 46.0, 57.0, 67.6, 44.6, 45.3, 44.7, 50.4])
models = np.array(["human", "LLaMA-7B (z-s)", "LLaMA2-7B (z-s)", "LLaMA2-7B-Chat (z-s)", "InstructGPT (z-s)", "ChatGPT (z-s)", "Med-PaLM (z-s)", "LLaMA2-7B (f-t)", "LLaMA2-7b-Chat (f-t)", "PMC-LLaMA (f-t)", "BioMedGPT (f-t) (Ours)"])
#colors = np.array(["#D75A3D", "#E3A250", "#F0DF5F", "#A2C854", "#2E9F61", "#20A19F", "#13A4D8", "#3A7AB3", "#4F488B", "#99518D"])
colors = np.array(["#405de6", "#5851db", "#833ab4", "#c13584", "#e1306c", "#fd1d1d", "#f56040", "#f77737", "#fcaf45", "#ffdc80"])
for i in range(10):
    #plt.bar([x[i], x[i] + 12, x[i] + 24], [y1[i], y2[i], y3[i]], width=0.8, color=colors[9 - i])
    plt.bar([x[i]], [y2[i]], width=0.8, color=colors[9 - i])
plt.xticks([], [])
#plt.xticks([5, 17, 29], ["MedMCQA (In-Domain)", "PubMedQA (In-Domain)", "USMLE (Out-of-Domain)"])
plt.ylabel("Accuracy (%)")
plt.ylim(0, 100)
#plt.plot([0, 10], [60, 60], color="grey", linestyle="--", linewidth=2)
plt.plot([0, 10], [78, 78], color="black", linestyle="--", linewidth=2)
plt.legend(models, ncols=1, loc=[1.01, 0.1])
#plt.plot([24, 34], [50, 50], color="grey", linestyle="--", linewidth=2)
#plt.plot([24, 34], [87, 87], color="black", linestyle="--", linewidth=2)
#plt.plot([0, 10], [90, 90], color="black", linestyle="--", linewidth=2)
plt.savefig("./biomedqa.png")

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(30, 8))
plt.rcParams.update({'font.size': 18})
x = np.arange(7)

y1 = np.array([80.6, 77.7, 87.2, 92.1, 93.2, 88.4, 96.6])
z1 = np.array([0.6, 0.7, 0.6, 0.4, 0.5, 0.7, 0.4])
y2 = np.array([75.6, 74.7, 75.7, 78.0, 79.7, 76.0, 80.4])
z2 = np.array([2.1, 1.9, 3.0, 3.6, 3.4, 3.0, 3.3])
y3 = np.array([77.4, 70.6, 82.2, 82.0, 82.6, 87.7, 88.5])
z3 = np.array([3.3, 5.0, 3.9, 3.2, 1.3, 3.7, 2.2])
y4 = np.array([72.8, 70.5, 66.9, 68.1, 69.9, 68.7, 74.7])
z4 = np.array([1.7, 1.4, 4.4, 5.0, 4.1, 2.8, 4.0])


y1 = np.array([82.4, 79.6, 88.0, 92.7, 93.1, 93.2, 96.6])
z1 = np.array([0.8, 0.7, 0.4, 0.4, 0.5, 0.5, 0.1])
y2 = np.array([77.7, 69.7, 82.3, 83.7, 85.8, 84.5, 92.5])
z2 = np.array([4.6, 4.3, 2.2, 1.9, 1.2, 1.6, 3.8])
y3 = np.array([72.8, 67.2, 78.2, 78.0, 77.3, 87.2, 93.7])
z3 = np.array([4.6, 3.0, 5.1, 5.0, 5.7, 1.2, 1.2])
y4 = np.array([69.0, 66.3, 70.0, 68.2, 70.2, 82.2, 88.4])
z4 = np.array([1.2, 4.1, 5.0, 4.3, 3.3, 1.4, 2.6])


#colors = np.array(["#D75A3D", "#E3A250", "#F0DF5F", "#A2C854", "#2E9F61", "#20A19F", "#13A4D8", "#3A7AB3", "#4F488B", "#99518D"])
colors = np.array(["#9B9B9B", "#FFB72C", "#EA7134", "#aea400", "#409D6D", "#9DC3E7", "#3768B8"])
#colors = np.array(["#D76364", "#EF7A6D", "#F1D77E", "#63E398", "#B1CE46", "#9DC3E7", "#3768B8"])
models = ["RF", "SVM", "DeepDTA", "GraphDTA", "MGraphDTA", "KGE_NFM", "KEDD"]
for i in range(7):
    #plt.bar([x[i], x[i] + 12, x[i] + 24], [y1[i], y2[i], y3[i]], width=0.8, color=colors[9 - i])
    plt.bar([x[i], x[i] + 10, x[i] + 20, x[i] + 30], [y1[i], y2[i], y3[i], y4[i]], width=0.8, color=colors[i])
for i in range(7):
    plt.errorbar([x[i]], [y1[i]], yerr=[z1[i]], color='black', elinewidth=0.8, capsize=8)
    plt.errorbar([x[i] + 10], [y2[i]], yerr=[z2[i]], color='black', elinewidth=0.8, capsize=8)
    plt.errorbar([x[i] + 20], [y3[i]], yerr=[z3[i]], color='black', elinewidth=0.8, capsize=8)
    plt.errorbar([x[i] + 30], [y4[i]], yerr=[z4[i]], color='black', elinewidth=0.8, capsize=8)
plt.xticks([3, 13, 23, 33], ["Warm-start", "Cold-drug", "Cold-protein", "Cold-cluster"])
plt.ylabel("AUROC (%)")
plt.ylim(50, 100)

plt.legend(models, ncols=7, loc=(0.18, -0.14))

plt.savefig("./BMKG.png")

# %%
x = np.arange(5)
y1 = np.array([88.0, 92.7, 93.1, 93.2, 96.6])
z1 = np.array([0.4, 0.4, 0.5, 0.5, 0.1])
y2 = np.array([82.3, 83.7, 85.8, 84.5, 92.5])
z2 = np.array([2.2, 1.9, 1.2, 1.6, 3.8])
y3 = np.array([78.2, 78.0, 77.3, 87.2, 93.7])
z3 = np.array([5.1, 5.0, 5.7, 1.2, 1.2])
y4 = np.array([70.0, 68.2, 70.2, 82.2, 88.4])
z4 = np.array([5.0, 4.3, 3.3, 1.4, 2.6])

# %%
def connect_ht(scores):
    return np.concatenate((scores, [scores[0]]))

names = ['Function', 'Name', 'Family', 'Subcellular Location']
scores_biomedgpt = [0.620, 0.684, 0.927, 0.793]
scores_llama2 = [0.078, 0.018, 0.205, 0.083]
scores_instructprotein = [0.054, 0.089, 0.088, 0.080]
scores_gal = [0.041, 0.054, 0.001, 0.047]
scores_chatgpt = [0.089, 0.113, 0.112, 0.079]
theta = np.linspace(0, 2 * np.pi, len(names), endpoint=False)
theta = np.concatenate((theta, [theta[0]]))  
scores_biomedgpt = connect_ht(scores_biomedgpt)
scores_llama2 = connect_ht(scores_llama2)
scores_instructprotein = connect_ht(scores_instructprotein)
scores_gal = connect_ht(scores_gal)
scores_chatgpt = connect_ht(scores_chatgpt)
plt.figure(figsize=(24, 8))
plt.rcParams.update({'font.size': 16})
ax = plt.subplot2grid(shape=(1, 2), loc=(0, 1), projection='polar')
ax.plot(theta, scores_biomedgpt, color='#0087d2', marker='o')
ax.fill(theta, scores_biomedgpt, color='#0087d2', alpha=0.2, label="biomedgpt")
ax.plot(theta, scores_llama2, color='#6561ac', marker='o')
ax.fill(theta, scores_llama2, color='#6561ac', alpha=0.2, label="LLaMA2-7B-Chat")
ax.plot(theta, scores_instructprotein, color='#0eb24e', marker='o')
ax.fill(theta, scores_instructprotein, color='#0eb24e', alpha=0.2, label="MolInstructions")
ax.plot(theta, scores_gal, color='#f37023', marker='o')
ax.fill(theta, scores_gal, color='#f37023', alpha=0.2, label="Galactica-7B")
ax.plot(theta, scores_chatgpt, color='#cd004b', marker='o')
ax.fill(theta, scores_chatgpt, color='#cd004b', alpha=0.2, label="ChatGPT")
ax.set_xticks(theta[:-1])
ax.set_xticklabels(names)
for i, label in enumerate(ax.get_xticklabels()):
    blank = 0.02 if i % 2 == 1 else 0.1
    label.set_y(label.get_position()[1] - blank)
ax.set_yticks([0.05, 0.5, 0.8])
ax.set_ylim(0, 1)
plt.legend(loc=[0.95, 0.83])

names = ['Description', 'IUPAC Name', 'Molecular Formula', 'HBD', 'HBA', 'Rotatable bonds', 'LogP', 'TPSA']
scores_biomedgpt = [0.310, 0.180, 0.595, 0.488, 0.309, 0.227, 0.260, 0.154]
scores_llama2 = [0.079, 0.109, 0.170, 0.017, 0.030, 0.029, 0.018, 0.006]
scores_molinstruct = [0.327, 0.008, 0.053, 0.042, 0.034, 0.045, 0.086, 0.017]
scores_gal = [0.001, 0.010, 0.153, 0.104, 0.027, 0.024, 0.086, 0.010]
scores_chatgpt = [0.049, 0.196, 0.079, 0.005, 0.002, 0.004, 0.006, 0.002]
theta = np.linspace(0, 2 * np.pi, len(names), endpoint=False)
theta = np.concatenate((theta, [theta[0]]))  
scores_biomedgpt = connect_ht(scores_biomedgpt)
scores_llama2 = connect_ht(scores_llama2)
scores_molinstruct = connect_ht(scores_molinstruct)
scores_gal = connect_ht(scores_gal)
scores_chatgpt = connect_ht(scores_chatgpt)
ax = plt.subplot2grid(shape=(1, 2), loc=(0, 0), projection='polar')
ax.plot(theta, scores_biomedgpt, color='#0087d2', marker='o')
ax.fill(theta, scores_biomedgpt, color='#0087d2', alpha=0.2, label="biomedgpt")
ax.plot(theta, scores_llama2, color='#6561ac', marker='o')
ax.fill(theta, scores_llama2, color='#6561ac', alpha=0.2, label="LLaMA2-7B-Chat")
ax.plot(theta, scores_molinstruct, color='#0eb24e', marker='o')
ax.fill(theta, scores_molinstruct, color='#0eb24e', alpha=0.2, label="MolInstructions")
ax.plot(theta, scores_gal, color='#f37023', marker='o')
ax.fill(theta, scores_gal, color='#f37023', alpha=0.2, label="Galactica-7B")
ax.plot(theta, scores_chatgpt, color='#cd004b', marker='o')
ax.fill(theta, scores_chatgpt, color='#cd004b', alpha=0.2, label="ChatGPT")
ax.set_xticks(theta[:-1])
ax.set_xticklabels(names)
blank = [0.2, 0.15, 0.02, 0.12, 0.1, 0.15, 0.02, 0.12]
for i, label in enumerate(ax.get_xticklabels()):
    label.set_y(label.get_position()[1] - blank[i])
ax.set_yticks([0.1, 0.2, 0.5])
ax.set_ylim(0, 0.65)
plt.legend(loc=[1.08, 0.83])
plt.show()
